# %%
import tabula

# %%
for i in range(1,20,1):
    df = tabula.read_pdf(r"anesthesia" + str(i)+ ".pdf", pages='all')
    tabula.convert_into(r"anesthesia" + str(i)+ ".pdf", "anesthesia" + str(i)+ ".csv", output_format="csv", pages='all')
# Out:
# Got stderr: Jan 06, 2023 9:08:44 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_121
# Jan 06, 2023 9:08:44 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Jan 06, 2023 9:08:44 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Jan 06, 2023 9:08:44 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Jan 06, 2023 9:08:44 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Jan 06, 2023 9:08:44 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")
#
# Got stderr: Jan 06, 2023 9:08:54 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# ...

# %%
df
# Out:
# [   Unnamed: 0      Value File Date/Time           Captured By  Edit History
#  0     O2 Flow  0.7 L/min  11/15/22 1600  Interface, Device In           NaN
#  1         NaN  0.7 L/min  11/15/22 1601  Interface, Device In           NaN
#  2         NaN  0.7 L/min  11/15/22 1602  Interface, Device In           NaN
#  3         NaN  0.7 L/min  11/15/22 1603  Interface, Device In           NaN
#  4         NaN  0.7 L/min  11/15/22 1604  Interface, Device In           NaN
#  5         NaN  0.7 L/min  11/15/22 1605  Interface, Device In           NaN
#  6         NaN  1.9 L/min  11/15/22 1606  Interface, Device In           NaN
#  7         NaN  1.9 L/min  11/15/22 1607  Interface, Device In           NaN
#  8         NaN  1.9 L/min  11/15/22 1608  Interface, Device In           NaN
#  9         NaN  1.9 L/min  11/15/22 1609  Interface, Device In           NaN
#  10        NaN  1.9 L/min  11/15/22 1610  Interface, Device In           NaN
# ...
